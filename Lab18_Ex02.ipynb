// %% [markdown]
// # Lab 18 Exercise 2

// %% [markdown]
// ## Generic

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab18_Ex02
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// var name  = new DataStore<string>();
// name.value ="Name LName";
// System.Console.WriteLine(name.value);
//
// var id = new DataStore<int>();
// id.value = 1234;
// System.Console.WriteLine(id.value);
//
// var gpa = new DataStore<float>();
// gpa.value = 3.45f;
// System.Console.WriteLine(gpa.value);
//
// public class DataStore <T>
// {
//     private T data;
//     public T value
//     {
//         get { return this.data; }
//         set { this.data = value;}
//     }
//
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab18_Ex02
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab18_Ex02
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// เมื่อรันโค้ดข้อมูลที่เก็บในตัวแปร name.value, id.value, และ gpa.value จะถูกแสดงผลออกมาทางคอนโซล
