// %% [markdown]
// # Lab 18 Exercise 10

// %% [markdown]
// ## Generic stack

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab18_Ex10
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// using System;
// using System.Collections.Generic;
//
// Stack<string> planets = new Stack<string>();
//
// System.Console.WriteLine("Push planets (Mercury to Pluto) into stack");
// planets.Push("Mercury");
// planets.Push("Venus");
// planets.Push("Earth");
// planets.Push("Mars");
// planets.Push("Jupiter");
// planets.Push("Saturn");
// planets.Push("Uranus");
// planets.Push("Neptune");
// planets.Push("Pluto");
//
// System.Console.WriteLine("Items in stack:");
// foreach (var item in planets)
// {
//     System.Console.WriteLine(item);
// }
//
// System.Console.Write("Remove first item in queue : ");
// var popItem = planets.Pop();
// System.Console.WriteLine(popItem);
//
// System.Console.WriteLine("Remaining items in queue:");
// foreach (var item in planets)
// {
//     System.Console.WriteLine(item);
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab18_Ex10
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab18_Ex10
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
//  Stack ใช้หลักการ LIFO (Last In, First Out) ค่า Pluto ที่ถูก push เข้าไปล่าสุดจะถูก pop ออกมาก่อน ค่าที่เหลือใน stack ยังคงเรียงตามลำดับที่ push เข้ามา
